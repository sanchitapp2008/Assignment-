# %% [markdown]
# <a href="https://colab.research.google.com/github/sanchitapp2008/Assignment-/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Enter a number: 8
# Even number

# %%
x = input("Enter something: ")

if x.isdigit():
    print("It is a Number")
else:
    print("It is a Character")
# Out:
# Enter something: 10
# It is a Number
